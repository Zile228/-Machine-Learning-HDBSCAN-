# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sbn
from sklearn.decomposition import PCA

# %%
df=pd.read_csv('C:/Users/tienv/Downloads/make_moons.csv')
print(df.head(5))
# Out:
#           X         Y  label
# 0 -1.129064 -0.049047      0
# 1  0.264658  0.960315      0
# 2  0.604729  0.585562      0
# 3 -0.603916  0.789943      0
# 4 -0.591466  0.712346      0

# %%
df = df.drop(columns=['label'], errors='ignore')
df.head()
# Out:
#           X         Y
# 0 -1.129064 -0.049047
# 1  0.264658  0.960315
# 2  0.604729  0.585562
# 3 -0.603916  0.789943
# 4 -0.591466  0.712346

# %%
# kiểm tra missing value
df.isnull().sum()
# Out:
# X    0
# Y    0
# dtype: int64

# %%
# thống kê cơ bản
df.describe()
# Out:
#                  X            Y
# count  1000.000000  1000.000000
# mean      0.491528     0.251111
# std       0.871544     0.498634
# min      -1.263013    -0.746779
# 25%      -0.095972    -0.193826
# 50%       0.489457     0.256987
# 75%       1.032766     0.680219
# max       2.254077     1.255355

# %%
df.drop_duplicates(inplace=True) # bỏ dòng trùng

# %%
# boxplot kiểm tra outlier 
df[['X','Y']].boxplot(figsize=(10,5))
plt.show()

# %%
#chuẩn hóa z score
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=X.columns)
df_scaled.head()
# Out:
#           X         Y
# 0 -1.860379 -0.602261
# 1 -0.260439  1.423004
# 2  0.129951  0.671069
# 3 -1.257529  1.081156
# 4 -1.243236  0.925459

# %%
plt.figure(figsize=(6, 5))
plt.scatter(df_scaled.iloc[:, 0], df_scaled.iloc[:, 1], s=20)
plt.title("Dữ liệu sau khi chuẩn hóa")
plt.xlabel(df_scaled.columns[0])
plt.ylabel(df_scaled.columns[1])
plt.show()

# %%
df_scaled.to_csv("moon_scaled_tienxuli.csv", index=False)
print("Đã xuất file")
# Out:
# Đã xuất file
